# %%
#Making an Atm of X bank
user_namelist=[]
user_passwordlist=[]
bankbalance_ofuserlist=[]


while True:
 user_name=input("what is your name")
 if user_name.lower()=="none":
   break
 
 user_password=int(input("what is your password"))
 bankbalance_ofuser=float(input("what is your balance"))
 
 

 user_namelist.append(user_name)                       
 user_passwordlist.append(user_password)
 bankbalance_ofuserlist.append(bankbalance_ofuser)

print("\n All data:")
print("user name list",user_namelist)
print("user password list",user_passwordlist)
print("bank balance list",bankbalance_ofuserlist)


givenuser_name=input("please enter your name")
givenuser_password=int(input("your  password please"))
if givenuser_name in user_namelist:
 index = user_namelist.index(givenuser_name)
 if user_passwordlist[index] == givenuser_password:
      print("your entry is succesful")
 else:
      print("your password is incorrect.")
        
else:
      print("Your username is unknown. Please try again later.")



          
def finding_username(index,givenuser_name):
    
    index=user_namelist.index(givenuser_name)
    print(f"the nametyped and its index are  {givenuser_name} and {index}")

def displaying_balance(index):
    index=user_namelist.index(givenuser_name)
    current_balance=bankbalance_ofuserlist[index]
    print(f"Current deposit belonging to {givenuser_name} is {current_balance:.2f} ")

def withdrawdeposit(index,moneywithdrawn):
    
    index=user_namelist.index(givenuser_name)
    if bankbalance_ofuserlist[index]>=moneywithdrawn:
     residual_deposit=bankbalance_ofuserlist[index]-moneywithdrawn
     print(f"{givenuser_name}'s residual_deposit is {residual_deposit:.2f}")

    else:
     print("you do not have enough deposit to withdraw on your bank account")

def depositing_money(index,deposedmoney):
    
     index=user_namelist.index(givenuser_name)
     total_balance=bankbalance_ofuserlist[index]+deposedmoney
     print("The total balance of {} is {}".format(givenuser_name,total_balance))

def changing_password(index,new_password):
    
     index=user_namelist.index(givenuser_name)
     old_password= user_passwordlist[index]
     user_passwordlist[index]=new_password
     print(f"Available password changed from  {old_password} to {new_password}")

while True:
 print("Welcome to our bank")
 print("Press first button to find user name and your index")
 print("Press second button so as to look your current balance")
 print("Press third button in order to withdraw deposit")
 print("Press fourth button to deposit money in your bank account")
 print("Press fifth button to change available password")
 print("Press sixth button to EXIT")



 selection=input("which button do you want to press")
 
 if selection=="1":
    
  finding_username(index,givenuser_name)
 
 elif selection=="2":
  
  displaying_balance(index)  

 elif selection=="3":
    
  moneywithdrawn=float(input("How much money do you want  to withdraw?"))
  withdrawdeposit(index,  moneywithdrawn)

 elif selection=="4":
  deposedmoney=float(input("How much money do you want to deposit money in your bank account?"))
  depositing_money(index,deposedmoney)
 
 elif selection=="5":
  new_password=int(input("determine a new password"))
  changing_password(index,new_password)
 
 elif selection=="6":   
  break

 else:
  print("Invalid selection.Please try again later")
